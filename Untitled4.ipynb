# %% [markdown]
# <a href="https://colab.research.google.com/github/vinipedro629/APIS-de-navegador-comunicando-com-o-servidor/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-11o_cze6
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-11o_cze6
#   Resolved https://github.com/openai/whisper.git to commit 517a43ecd132a2089d85f4ebc044728a71d49f6e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 68.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 53.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...

# %%
# !whisper "teste.mp3" --model medium
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/whisper/audio.py", line 58, in load_audio
#     out = run(cmd, capture_output=True, check=True).stdout
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/subprocess.py", line 571, in run
#     raise CalledProcessError(retcode, process.args,
# subprocess.CalledProcessError: Command '['ffmpeg', '-nostdin', '-threads', '0', '-i', 'teste.mp3\xa0--model\xa0medium', '-f', 's16le', '-ac', '1', '-acodec', 'pcm_s16le', '-ar', '16000', '-']' returned non-zero exit status 1.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/whisper/transcribe.py", line 615, in cli
#     result = transcribe(model, audio_path, temperature=temperature, **args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !whisper "teste.mp3" --model medium
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: Portuguese
# [00:00.000 --> 00:13.000]  Hoje eu acordei, eu pensei, pô, sabe o que eu tô afim de fazer? Tô afim de botar uma gravata, uma camisa de botão, pegar um ônibus apertado assim, lotado de gente e ir lá ganhar dinheiro pro meu empregador.
# [00:13.000 --> 00:28.000]  Eu nunca quis fazer isso na minha vida, nem um dia da minha vida eu acordei assim, nem um dia eu nunca quis trabalhar, assim como quando eu era criança eu não queria escovar os dentes geralmente, ou não queria tomar banho, mas tinha que fazer.
# [00:28.000 --> 00:36.000]  Trabalho pra mim sempre foi assim, tá? Eu percebi muito cedo, eu percebi quando eu tinha 16 anos de idade que, bom, eu era muito bom num jogo chamado Hearthstone.
# ...
